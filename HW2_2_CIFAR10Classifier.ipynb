# %% [markdown]
# This can be run [run on Google Colab using this link](https://colab.research.google.com/github/CS7150/CS7150-Homework-2/blob/main/HW2_2_CIFAR10Classifier.ipynb)
#
# <font size='6'>**Homework 2.2: Neural Network CIFAR-10 Classification**</font>

# %% [markdown]
# ** I REALIZED THE PRINT FUNCTIONALITY TRUNCATES THE PDF FILE SOMETIMES, SO PLEASE REFER TO THE LINKS BELOW TO ACCESS THE COLAB OR GITHUB VERSION IF ANYTHING UNCLEAR**
#
# **COLAB LINK BELOW**
#
# https://drive.google.com/file/d/1LeZuNojGcFetumP_FNxL87bYw1HV5I3L/view?usp=sharing
#
# **GITHUB LINK BELOW**
#
# https://github.com/babelpainterwell/Adam-Optimizer-Implementation

# %% [markdown]
# <font size='5'>**Overview**</font>
#
# In this CS7150 assignment, our objective is to build a neural network featuring two fully-connected layers designed for classification purposes. We will evaluate the performance of this neural network by testing it on the CIFAR-10 dataset.
#
# This assignment adheres to a standard classification setup, which encompasses the use of a dataloader to load labeled image data in a natural form and training the model in a minibatch-based fashion.
#
# **Your assignment**: Your responsibility throughout this notebook is to thoroughly review the content and address all the conceptual and technical questions identified within the sections marked with "Task" headers and "TODO:" comments in the code.

# %% [markdown]
# <font size='5'>**I) Setup**</font>

# %%
import os
import torch
from torch import nn
from torchvision.datasets import CIFAR10
from torchvision.transforms import Compose, ToTensor
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# <font size='4'>**Device Setup**</font>

# %% [markdown]
# We aim to enable model training on a GPU to expedite our computations. First, we'll check whether torch.cuda is accessible; if it is, we will utilize the GPU; otherwise, we will continue to using the CPU.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# <font size='4'>**Loading CIFAR-10 Data**</font>

# %% [markdown]
# The CIFAR-10 dataset comprises a collection of 60,000 32x32 color images distributed across ten distinct classes. These classes correspond to various objects and include airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. Within each class, there are precisely 6,000 images.

# %%
# downloading cifar10 into folder
data_dir = 'cifar10_data' # make sure that this folder is created in your working dir

#TODO: Fill out train_data and test_data variables using CIFAR10 (i.e., torchvision.datasets.CIFAR)
train_data = CIFAR10(data_dir, train=True, download=True, transform=Compose([ToTensor()]))
test_data = CIFAR10(data_dir, train=False, download=True, transform=Compose([ToTensor()]))
#train_data = None
#test_data = None
print(f'Datatype of the dataset object: {type(train_data)}')
# check the length of dataset
print(f'Number of samples in training data: {len(train_data)}')
print(f'Number of samples in test data: {len(test_data)}')
# Check the format of dataset
print(f'Format of the dataset: \n {train_data}')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar10_data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 42007362.75it/s]
# Extracting cifar10_data/cifar-10-python.tar.gz to cifar10_data
# Files already downloaded and verified
# Datatype of the dataset object: <class 'torchvision.datasets.cifar.CIFAR10'>
# Number of samples in training data: 50000
# Number of samples in test data: 10000
# Format of the dataset:
#  Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: cifar10_data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %% [markdown]
# ### <font size='4'>**Displaying Loaded Dataset**</font>

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2, 3, i+1)
  plt.tight_layout()
  plt.imshow(train_data[i][0][0], cmap='gray', interpolation='none')
  plt.title("Class Label: {}".format(train_data[i][1]))
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# ## <font size='5'>**II) Building a Neural Network**</font>

# %% [markdown]
# ### <font size='4'>**1) Defining `CIFAR10Classifier` class**</font>

# %% [markdown]
# <font size='4' color='Red'>Task 1.1 - Defining `CIFAR10Classifier` class (4 points)</font>
#
# In the following class, make adjustments to the following attributes: flatten, hidden_size, class_size, and linear_relu_stack. Ensure that the linear_relu_stack consists of a minimum of two linear layers combined with a non-linear activation layer.

# %%
class CIFAR10Classifier(nn.Module):
    def __init__(self):
        super(CIFAR10Classifier, self).__init__()
        ########################################################################
        # TODO: Complete the following variables as instructed earlier
        ########################################################################
        self.flatten = nn.Flatten()
        self.hidden_size = 2048
        self.class_size = 10
        self.input_size = 3 * 32 * 32
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(self.input_size, self.hidden_size),
            nn.ReLU(),
            nn.Linear(self.hidden_size, self.hidden_size),  # hidden layer
            nn.ReLU(),
            # nn.Linear(self.hidden_size, self.hidden_size),  # hidden layer
            # nn.ReLU(),
            nn.Linear(self.hidden_size, self.class_size)   # output layer
        )
        ########################################################################
        #                             END OF YOUR CODE                         #
        ########################################################################

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %% [markdown]
# ### <font size='4'>**2) Training a Neural Network**</font>

# %% [markdown]
# <font size='4' color='Red'>Task 1.2 - Defining parameters (3 points)</font>

# %% [markdown]
# Let's create an instance of `CIFAR10Classifier` and move it to the device. After doing so, we define the following hyperparameters for training:
#
# - **Number of Epochs**: This signifies the number of iterations over the dataset.
# - **Batch Size**: It represents the number of data samples that propagate through the network before parameter updates.
# - **Learning Rate**: This parameter determines the extent of model parameter updates during each batch/epoch. Smaller values lead to slower learning, while larger values may introduce instability during training.
#
# **Your Task**:
#
# 1. Set `learning_rate` to 1e-3, `batch_size` to 64, and `epochs` to 10 initially. Experiment with different values and retain the final choices that yield the highest testing accuracy.
#
# 2. Select an appropriate loss function. You should experiment with different options, such as `CrossEntropyLoss()`, `MSELoss()`, and any others, and choose the one that best suits the task.
#
# 3. Define the `optimizer` variable using any optimizer function (e.g., SGD, Adam, etc.). Be sure to explore different parameter values within the chosen optimizer function.
#
# 4. Remember to record your ultimate choices for each variable that contribute to achieving the best performance for your `CIFAR10Classifier`. To receive full credit for this assignment, your model should attain a classification accuracy of over 50% on the test set.

# %%
model = CIFAR10Classifier().to(device)
model.requires_grad_(True)

########################################################################
# TODO: Complete the following variables as instructed earlier
########################################################################

learning_rate = 1e-2
batch_size = 64
momentum = 0.9
epochs = 15
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, weight_decay=1e-3, momentum=momentum)

########################################################################
#                             END OF YOUR CODE                         #
########################################################################

# %% [markdown]
# ### <font size='4'>**3) Train Loop**</font>

# %%
train_dataloader = DataLoader(train_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# In the above cell, we used a Dataloader to create batches for training and testing data. For each batch of size indicated in the batch_size hyperparameter, we perform backprop and update the model parameters' weights and biases.
#
# In the following cell, we define our train_loop.

# %%
def train_loop(dataloader, model, loss_fn, optimizer, print_log=True):
    size = len(dataloader.dataset)
    correct = 0
    training_acc = 0
    training_loss = 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X.to(device))
        loss = loss_fn(pred, y.to(device))
        correct += (pred.argmax(1) == y.to(device)).type(torch.float).sum().item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        loss, current = loss.item(), batch * len(X)
        training_loss = loss
        if (print_log==True) and (batch % 100 == 0):
          print(f"""Training loop: loss: {loss:>7f}  [{current:>5d}/{size:>5d}]""")
    correct /= size
    training_acc = 100*correct
    if (print_log==True):
        print(f"""Training Accuracy: {training_acc:>0.1f}%""")
    return training_acc, training_loss

# %% [markdown]
# ### <font size='4'>**4) Test Loop**</font>

# %% [markdown]
# In the test loop, we iterate over the test dataset to check if model performance is improving.

# %%
def test_loop(dataloader, model, loss_fn, print_log=True):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X.to(device))
            test_loss += loss_fn(pred, y.to(device)).item()
            correct += (pred.argmax(1) == y.to(device)).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    testing_acc = 100*correct
    if (print_log==True):
        print(f"Testing Accuracy: {testing_acc:>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return testing_acc, test_loss

# %% [markdown]
# ### <font size='4'>**5) Running the loops**</font>

# %% [markdown]
# We run our loops for a certain number of times, which is indicated in the 'epoch' hyperparameter that we defined earlier. In the following cell, we run both our training and testing loop to see how our training and testing accuracies change over time.

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loop: loss: 2.312544  [    0/50000]
# Training loop: loss: 2.007059  [ 6400/50000]
# Training loop: loss: 1.653037  [12800/50000]
# Training loop: loss: 1.908516  [19200/50000]
# Training loop: loss: 1.947395  [25600/50000]
# Training loop: loss: 1.889127  [32000/50000]
# Training loop: loss: 1.799346  [38400/50000]
# Training loop: loss: 1.689039  [44800/50000]
# Training Accuracy: 33.5%
# Testing Accuracy: 40.4%, Avg loss: 1.677369
#
# Epoch 2
# -------------------------------
# Training loop: loss: 1.714247  [    0/50000]
# Training loop: loss: 1.639258  [ 6400/50000]
# Training loop: loss: 1.405635  [12800/50000]
# Training loop: loss: 1.777470  [19200/50000]
# Training loop: loss: 1.644978  [25600/50000]
# Training loop: loss: 1.672384  [32000/50000]
# Training loop: loss: 1.668088  [38400/50000]
# Training loop: loss: 1.626420  [44800/50000]
# Training Accuracy: 41.4%
# Testing Accuracy: 43.8%, Avg loss: 1.590084
#
# Epoch 3
# -------------------------------
# Training loop: loss: 1.617973  [    0/50000]
# Training loop: loss: 1.506709  [ 6400/50000]
# Training loop: loss: 1.331047  [12800/50000]
# Training loop: loss: 1.721796  [19200/50000]
# Training loop: loss: 1.516498  [25600/50000]
# Training loop: loss: 1.612085  [32000/50000]
# Training loop: loss: 1.617796  [38400/50000]
# Training loop: loss: 1.582410  [44800/50000]
# Training Accuracy: 44.5%
# Testing Accuracy: 45.8%, Avg loss: 1.529767
#
# Epoch 4
# -------------------------------
# Training loop: loss: 1.560430  [    0/50000]
# Training loop: loss: 1.449499  [ 6400/50000]
# Training loop: loss: 1.262131  [12800/50000]
# Training loop: loss: 1.654128  [19200/50000]
# Training loop: loss: 1.458094  [25600/50000]
# Training loop: loss: 1.568959  [32000/50000]
# Training loop: loss: 1.571840  [38400/50000]
# Training loop: loss: 1.521429  [44800/50000]
# Training Accuracy: 46.4%
# Testing Accuracy: 46.6%, Avg loss: 1.505792
#
# Epoch 5
# -------------------------------
# Training loop: loss: 1.539912  [    0/50000]
# Training loop: loss: 1.425733  [ 6400/50000]
# Training loop: loss: 1.236268  [12800/50000]
# Training loop: loss: 1.591200  [19200/50000]
# Training loop: loss: 1.404296  [25600/50000]
# Training loop: loss: 1.551394  [32000/50000]
# Training loop: loss: 1.527490  [38400/50000]
# Training loop: loss: 1.466946  [44800/50000]
# Training Accuracy: 47.9%
# Testing Accuracy: 48.2%, Avg loss: 1.460707
#
# Epoch 6
# -------------------------------
# Training loop: loss: 1.512020  [    0/50000]
# Training loop: loss: 1.412988  [ 6400/50000]
# Training loop: loss: 1.218019  [12800/50000]
# Training loop: loss: 1.548466  [19200/50000]
# Training loop: loss: 1.350380  [25600/50000]
# Training loop: loss: 1.501827  [32000/50000]
# Training loop: loss: 1.506271  [38400/50000]
# Training loop: loss: 1.411397  [44800/50000]
# Training Accuracy: 49.4%
# Testing Accuracy: 48.6%, Avg loss: 1.451293
#
# Epoch 7
# -------------------------------
# Training loop: loss: 1.479626  [    0/50000]
# Training loop: loss: 1.381261  [ 6400/50000]
# Training loop: loss: 1.172608  [12800/50000]
# Training loop: loss: 1.548338  [19200/50000]
# Training loop: loss: 1.290442  [25600/50000]
# Training loop: loss: 1.471649  [32000/50000]
# Training loop: loss: 1.478871  [38400/50000]
# Training loop: loss: 1.348362  [44800/50000]
# Training Accuracy: 50.9%
# Testing Accuracy: 48.8%, Avg loss: 1.444104
#
# Epoch 8
# -------------------------------
# Training loop: loss: 1.443079  [    0/50000]
# Training loop: loss: 1.381496  [ 6400/50000]
# Training loop: loss: 1.144912  [12800/50000]
# Training loop: loss: 1.492721  [19200/50000]
# Training loop: loss: 1.266153  [25600/50000]
# Training loop: loss: 1.450055  [32000/50000]
# Training loop: loss: 1.457490  [38400/50000]
# Training loop: loss: 1.340574  [44800/50000]
# Training Accuracy: 51.8%
# Testing Accuracy: 48.8%, Avg loss: 1.447695
#
# Epoch 9
# -------------------------------
# Training loop: loss: 1.441936  [    0/50000]
# Training loop: loss: 1.338323  [ 6400/50000]
# Training loop: loss: 1.162385  [12800/50000]
# Training loop: loss: 1.457863  [19200/50000]
# Training loop: loss: 1.234527  [25600/50000]
# Training loop: loss: 1.460026  [32000/50000]
# Training loop: loss: 1.402667  [38400/50000]
# Training loop: loss: 1.276167  [44800/50000]
# Training Accuracy: 52.8%
# Testing Accuracy: 50.2%, Avg loss: 1.407599
#
# Epoch 10
# -------------------------------
# Training loop: loss: 1.336137  [    0/50000]
# Training loop: loss: 1.322035  [ 6400/50000]
# Training loop: loss: 1.182657  [12800/50000]
# Training loop: loss: 1.387513  [19200/50000]
# Training loop: loss: 1.191423  [25600/50000]
# Training loop: loss: 1.440007  [32000/50000]
# Training loop: loss: 1.396174  [38400/50000]
# Training loop: loss: 1.261204  [44800/50000]
# Training Accuracy: 53.8%
# Testing Accuracy: 50.4%, Avg loss: 1.400214
#
# Epoch 11
# -------------------------------
# Training loop: loss: 1.351198  [    0/50000]
# Training loop: loss: 1.313978  [ 6400/50000]
# Training loop: loss: 1.161762  [12800/50000]
# Training loop: loss: 1.346475  [19200/50000]
# Training loop: loss: 1.168519  [25600/50000]
# Training loop: loss: 1.402320  [32000/50000]
# Training loop: loss: 1.369505  [38400/50000]
# Training loop: loss: 1.241163  [44800/50000]
# Training Accuracy: 54.8%
# Testing Accuracy: 50.0%, Avg loss: 1.403873
#
# Epoch 12
# -------------------------------
# Training loop: loss: 1.294188  [    0/50000]
# Training loop: loss: 1.284053  [ 6400/50000]
# Training loop: loss: 1.139693  [12800/50000]
# Training loop: loss: 1.334737  [19200/50000]
# Training loop: loss: 1.197698  [25600/50000]
# Training loop: loss: 1.367189  [32000/50000]
# Training loop: loss: 1.308326  [38400/50000]
# Training loop: loss: 1.224768  [44800/50000]
# Training Accuracy: 55.8%
# Testing Accuracy: 50.7%, Avg loss: 1.390544
#
# Epoch 13
# -------------------------------
# Training loop: loss: 1.227829  [    0/50000]
# Training loop: loss: 1.261389  [ 6400/50000]
# Training loop: loss: 1.101640  [12800/50000]
# Training loop: loss: 1.351957  [19200/50000]
# Training loop: loss: 1.118523  [25600/50000]
# Training loop: loss: 1.362506  [32000/50000]
# Training loop: loss: 1.284661  [38400/50000]
# Training loop: loss: 1.214785  [44800/50000]
# Training Accuracy: 56.7%
# Testing Accuracy: 51.0%, Avg loss: 1.392721
#
# Epoch 14
# -------------------------------
# Training loop: loss: 1.215426  [    0/50000]
# Training loop: loss: 1.224222  [ 6400/50000]
# Training loop: loss: 1.127567  [12800/50000]
# Training loop: loss: 1.272934  [19200/50000]
# Training loop: loss: 1.118570  [25600/50000]
# Training loop: loss: 1.303962  [32000/50000]
# Training loop: loss: 1.236002  [38400/50000]
# Training loop: loss: 1.205306  [44800/50000]
# Training Accuracy: 57.6%
# Testing Accuracy: 50.0%, Avg loss: 1.410002
#
# Epoch 15
# -------------------------------
# Training loop: loss: 1.276308  [    0/50000]
# Training loop: loss: 1.195901  [ 6400/50000]
# Training loop: loss: 1.089609  [12800/50000]
# Training loop: loss: 1.280446  [19200/50000]
# Training loop: loss: 1.052375  [25600/50000]
# Training loop: loss: 1.265439  [32000/50000]
# Training loop: loss: 1.143415  [38400/50000]
# Training loop: loss: 1.179066  [44800/50000]
# Training Accuracy: 58.6%
# Testing Accuracy: 50.5%, Avg loss: 1.391861
#
# Done!

# %% [markdown]
# ## <font size='5'>**III) Fine Tuning Hyperparameters**</font>

# %% [markdown]
# Adjusting the hyperparameters and gaining a deeper understanding of how they impact the ultimate performance is a substantial aspect of working with neural networks. Therefore, we encourage you to gain practical experience in this regard.

# %% [markdown]
# In this task, your goal is to play around with different settings for various options like layer size, batch size, learning rate. You should also experiment with optimizer hyperparameters including momentum, weight decay and more.
#
# To understand how these choices affect your model's performance, you'll create at least three graphs. Each graph will show how changing one of these options (except for epochs) impacts how well your model learns and predicts.

# %% [markdown]
# ## <font size='4'>**Example** - We've given you an example code for changing number of epochs so you can see how it's done.</font>

# %%
learning_rate = 1e-3
batch_size = 64
epochs = [1, 5, 10, 15, 20, 25]
momentum = 0
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for e in epochs: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = momentum,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(e):
        # print(f"Currently running epoch {t+1}")
        training_acc = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=False)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=False)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
plt.plot(epochs,test_losses, color ='tab:red', label='testing loss')
plt.plot(epochs,test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(epochs,training_accs, color ='tab:green', label='training accuracy')
plt.legend()
print("Done!")

# %% [markdown]
# <font size='4' color='Red'>Task 1.3 - Experiment 1 (2 point)</font>

# %% [markdown]
# $$\text{I am tuning _____momentum_________ hyperparameter for better performance}$$

# %%
############################################################################
# TODO: Implement your code here
############################################################################
# raise NotImplementedError
learning_rate = 1e-3
batch_size = 64
epochs = 15
momentum = [0.0, 0.3, 0.5, 0.8, 0.9, 0.99]
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for m in momentum: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = m,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        print(f"Currently running epoch {t+1}")
        training_acc = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=False)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=False)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)


# Plotting the testing loss in one diagram
plt.figure(figsize=(10, 5))
plt.plot(momentum, test_losses, color ='tab:red', label='testing loss')
plt.title('Testing Loss vs. Momentum')
plt.xlabel('Momentum')
plt.ylabel('Testing Loss')
plt.legend()
plt.show()

# Plotting the testing and training accuracy in another diagram
plt.figure(figsize=(10, 5))
plt.plot(momentum, test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(momentum, training_accs, color ='tab:green', label='training accuracy')
plt.title('Accuracy vs. Momentum')
plt.xlabel('Momentum')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

print("Done!")

############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.3 - Experiment 2 (2 point)</font>

# %% [markdown]
# $$\text{I am tuning _____batch_size_________ hyperparameter for better performance}$$

# %%
############################################################################
# TODO: Implement your code here
############################################################################
# raise NotImplementedError
learning_rate = 1e-3
batch_size = [128, 64, 32, 16, 8, 1]
epochs = 15
momentum = 0
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for b in batch_size: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = momentum,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=b)
    test_dataloader = DataLoader(test_data, batch_size=b)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        print(f"Currently running epoch {t+1}")
        training_acc = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=False)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=False)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)

# Plotting the testing loss in one diagram
plt.figure(figsize=(10, 5))
plt.plot(batch_size, test_losses, color ='tab:red', label='testing loss')
plt.title('Testing Loss vs. Batch_Size')
plt.xlabel('Momentum')
plt.ylabel('Testing Loss')
plt.legend()
plt.show()

# Plotting the testing and training accuracy in another diagram
plt.figure(figsize=(10, 5))
plt.plot(batch_size, test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(batch_size, training_accs, color ='tab:green', label='training accuracy')
plt.title('Accuracy vs. Batch_Size')
plt.xlabel('Batch_Size')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

print("Done!")

############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.4 - Experiment 3 (2 point)</font>

# %% [markdown]
# $$\text{I am tuning _____learning_rate_________ hyperparameter for better performance}$$

# %%
############################################################################
# TODO: Implement your code here
############################################################################
# raise NotImplementedError

learning_rate = [1, 0.1, 1e-2, 1e-3]
batch_size = 64
epochs = 15
momentum = 0
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for l in learning_rate: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = l,
                            momentum = momentum,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        print(f"Currently running epoch {t+1}")
        training_acc = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=False)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=False)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)

# Plotting the testing loss in one diagram
plt.figure(figsize=(10, 5))
plt.plot(learning_rate, test_losses, color ='tab:red', label='testing loss')
plt.title('Testing Loss vs. Learning_Rate')
plt.xlabel('Momentum')
plt.ylabel('Testing Loss')
plt.legend()
plt.show()

# Plotting the testing and training accuracy in another diagram
plt.figure(figsize=(10, 5))
plt.plot(learning_rate, test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(learning_rate, training_accs, color ='tab:green', label='training accuracy')
plt.title('Accuracy vs. Learning_Rate')
plt.xlabel('Learning_Rate')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

print("Done!")

############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Currently running epoch 1
# Currently running epoch 2
# Currently running epoch 3
# Currently running epoch 4
# Currently running epoch 5
# Currently running epoch 6
# Currently running epoch 7
# Currently running epoch 8
# Currently running epoch 9
# Currently running epoch 10
# Currently running epoch 11
# Currently running epoch 12
# Currently running epoch 13
# Currently running epoch 14
# Currently running epoch 15
# Done!
